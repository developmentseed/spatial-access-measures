# %%
import pandas as pd
import geopandas as gpd
import glob
from pathlib import Path

# %%
dissemination_boundary = gpd.read_file("data/DisseminationBoundary/ldb_000a21a_e.shp")

# %%
dissemination_boundary.head(2)
dissemination_boundary["DBUID"] = dissemination_boundary["DBUID"].astype(int)

# %%
file_paths = glob.glob("data/sam-msa-eng/acs*")
file_paths
# Out:
# ['data/sam-msa-eng/acs_cycling.csv',
#  'data/sam-msa-eng/acs_public_transit_offpeak.csv',
#  'data/sam-msa-eng/acs_walking.csv',
#  'data/sam-msa-eng/acs_public_transit_peak.csv']

# %%
dfs = []

for file in file_paths:
    df_ = pd.read_csv(file, encoding="latin1")
    df_["type"] = Path(file).stem
    df_["DBUID"] = df_["DBUID"].astype(int)
    dfs.append(df_)

sam = pd.concat(dfs)
type_column = sam.pop("type")
sam.insert(0, "type", type_column)
sam.head(2)
# Out:
#           type        DBUID   CSDUID     CSDNAME  CMAUID     CMANAME  PRUID  \
# 0  acs_cycling  10010165001  1001519  St. John's     1.0  St. John's     10
# 1  acs_cycling  10010165002  1001519  St. John's     1.0  St. John's     10
#
#   PRCODE  acs_idx_hf  acs_idx_emp  acs_idx_srf  acs_idx_psef  acs_idx_ef  \
# 0     NL    0.022759     0.042675     0.039388           0.0    0.031447
# 1     NL    0.021007     0.039877     0.035564           0.0    0.030209
#
#    acs_idx_caf       acs_lvl_gs-1 acs_lvl_gs-3        acs_lvl_gs-5
# 0     0.024913            5.94245      14.2529  15.599066666666666
# 1     0.022340  7.386466666666666  13.88188333  17.043066666666665

# %%
drop = [
    "CSDUID",
    "CMAUID",
    "PRUID_x",
    "PRCODE",
    "DBRPLAMX",
    "DBRPLAMY",
    "LANDAREA",
    "PRUID_y",
    "DGUID",
]

df = sam.merge(dissemination_boundary, left_on="DBUID", right_on="DBUID").drop(
    columns=drop
)

df = df.set_geometry("geometry")
df = df.to_crs(4326)

df = df.sort_values(by=["type", "CSDNAME"])
df = df.round(3)
df.head(2)
# Out:
#                type        DBUID          CSDNAME CMANAME  acs_idx_hf  \
# 479323  acs_cycling  59331465001  105 Mile Post 2     NaN         0.0
# 479324  acs_cycling  59331465002  105 Mile Post 2     NaN         0.0
#
#         acs_idx_emp  acs_idx_srf  acs_idx_psef  acs_idx_ef  acs_idx_caf  \
# 479323          0.0          0.0           0.0         0.0        0.001
# 479324          0.0          0.0           0.0         0.0        0.001
#
#        acs_lvl_gs-1 acs_lvl_gs-3 acs_lvl_gs-5  \
# 479323           ..           ..           ..
# 479324           ..           ..           ..
#
#                                                  geometry
# 479323  POLYGON ((-121.31321 50.75665, -121.31124 50.7...
# 479324  POLYGON ((-121.31321 50.75665, -121.31307 50.7...

# %%
len(df)
# Out:
# 1994188

# %%
df_flat = df.pivot(
    columns="type",
    index=["DBUID", "CSDNAME", "CMANAME", "geometry"],
    values=[
        "acs_idx_hf",
        "acs_idx_emp",
        "acs_idx_srf",
        "acs_idx_psef",
        "acs_idx_ef",
        "acs_idx_caf",
        "acs_lvl_gs-1",
        "acs_lvl_gs-3",
        "acs_lvl_gs-5",
    ],
)

df_flat.head()
# Out:
#                                                                                      acs_idx_hf  \
# type                                                                                acs_cycling
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...       0.023
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...       0.021
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...        0.02
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...       0.021
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...       0.022
#
#                                                                                                                 \
# type                                                                                acs_public_transit_offpeak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                      0.012
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                      0.014
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                      0.013
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                      0.014
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                      0.015
#
#                                                                                                              \
# type                                                                                acs_public_transit_peak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                    0.01
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                   0.012
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                   0.012
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                   0.012
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                   0.013
#
#                                                                                                  \
# type                                                                                acs_walking
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...       0.013
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...       0.011
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...       0.011
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...       0.013
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...       0.013
#
#                                                                                     acs_idx_emp  \
# type                                                                                acs_cycling
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...       0.043
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...        0.04
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...        0.04
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...       0.039
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...       0.042
#
#                                                                                                                 \
# type                                                                                acs_public_transit_offpeak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                      0.023
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                      0.027
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                      0.025
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                      0.026
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                      0.028
#
#                                                                                                              \
# type                                                                                acs_public_transit_peak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                   0.019
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                   0.023
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                   0.021
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                   0.022
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                   0.023
#
#                                                                                                  \
# type                                                                                acs_walking
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...       0.018
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...       0.014
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...       0.014
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...       0.018
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...       0.018
#
#                                                                                     acs_idx_srf  \
# type                                                                                acs_cycling
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...       0.039
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...       0.036
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...       0.035
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...       0.038
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...       0.039
#
#                                                                                                                 \
# type                                                                                acs_public_transit_offpeak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                       0.02
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                      0.024
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                      0.023
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                      0.022
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                      0.025
#
#                                                                                      ...  \
# type                                                                                 ...
# DBUID       CSDNAME    CMANAME    geometry                                           ...
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...  ...
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...  ...
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...  ...
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...  ...
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...  ...
#
#                                                                                                acs_lvl_gs-1  \
# type                                                                                acs_public_transit_peak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                    33.0
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                    28.0
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                    28.0
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                    33.0
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                    30.0
#
#                                                                                                         \
# type                                                                                       acs_walking
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...            5.94245
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...  7.386466666666666
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...  7.550683333333334
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                 ..
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                 ..
#
#                                                                                     acs_lvl_gs-3  \
# type                                                                                 acs_cycling
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...      14.2529
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...  13.88188333
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...  14.04611667
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...     14.63995
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...      14.8652
#
#                                                                                                                 \
# type                                                                                acs_public_transit_offpeak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                       37.0
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                       34.0
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                       35.0
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                       38.0
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                       32.0
#
#                                                                                                              \
# type                                                                                acs_public_transit_peak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                    37.0
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                    34.0
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                    35.0
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                    36.0
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                    32.0
#
#                                                                                                  \
# type                                                                                acs_walking
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...          ..
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...          ..
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...          ..
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...          ..
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...          ..
#
#                                                                                            acs_lvl_gs-5  \
# type                                                                                        acs_cycling
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...  15.599066666666666
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...  17.043066666666665
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...             17.2073
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...            18.15865
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...            17.61435
#
#                                                                                                                 \
# type                                                                                acs_public_transit_offpeak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                         ..
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                         ..
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                         ..
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                         ..
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                         ..
#
#                                                                                                              \
# type                                                                                acs_public_transit_peak
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...                      ..
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...                      ..
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...                      ..
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...                      ..
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...                      ..
#
#
# type                                                                                acs_walking
# DBUID       CSDNAME    CMANAME    geometry
# 10010165001 St. John's St. John's POLYGON ((-52.7765 47.52924, -52.77704 47.5286...          ..
# 10010165002 St. John's St. John's POLYGON ((-52.77963 47.52964, -52.77899 47.529...          ..
# 10010165006 St. John's St. John's POLYGON ((-52.77976 47.52879, -52.77951 47.528...          ..
# 10010165007 St. John's St. John's POLYGON ((-52.77421 47.52595, -52.77136 47.526...          ..
# 10010166001 St. John's St. John's POLYGON ((-52.77471 47.52662, -52.77366 47.527...          ..
#
# [5 rows x 36 columns]

# %%
df_flat.columns = [
    "_".join(col).strip() if isinstance(col, tuple) else col for col in df_flat.columns
]
df_flat = df_flat.reset_index()
df_flat = df_flat.set_geometry("geometry")
df_flat = df_flat.sort_values(by=["CSDNAME"])
print(len(df_flat))
# Out:
# 498547

# %%
df_flat.head()
# Out:
#               DBUID          CSDNAME CMANAME  \
# 479323  59331465001  105 Mile Post 2     NaN
# 479324  59331465002  105 Mile Post 2     NaN
# 479325  59331465003  105 Mile Post 2     NaN
# 479326  59331465004  105 Mile Post 2     NaN
# 479327  59331465005  105 Mile Post 2     NaN
#
#                                                  geometry  \
# 479323  POLYGON ((-121.31321 50.75665, -121.31124 50.7...
# 479324  POLYGON ((-121.31321 50.75665, -121.31307 50.7...
# 479325  POLYGON ((-121.31204 50.73864, -121.31205 50.7...
# 479326  POLYGON ((-121.31216 50.73497, -121.30969 50.7...
# 479327  POLYGON ((-121.30699 50.73491, -121.29582 50.7...
#
#        acs_idx_hf_acs_cycling acs_idx_hf_acs_public_transit_offpeak  \
# 479323                    0.0                                   0.0
# 479324                    0.0                                   0.0
# 479325                    0.0                                   0.0
# 479326                    0.0                                   0.0
# 479327                    0.0                                   0.0
#
#        acs_idx_hf_acs_public_transit_peak acs_idx_hf_acs_walking  \
# 479323                                0.0                    0.0
# 479324                                0.0                    0.0
# 479325                                0.0                    0.0
# 479326                                0.0                    0.0
# 479327                                0.0                    0.0
#
#        acs_idx_emp_acs_cycling acs_idx_emp_acs_public_transit_offpeak  ...  \
# 479323                     0.0                                    0.0  ...
# 479324                     0.0                                    0.0  ...
# 479325                     0.0                                    0.0  ...
# 479326                     0.0                                    0.0  ...
# 479327                     0.0                                    0.0  ...
#
#        acs_lvl_gs-1_acs_public_transit_peak acs_lvl_gs-1_acs_walking  \
# 479323                                   ..                       ..
# 479324                                   ..                       ..
# 479325                                   ..                       ..
# 479326                                   ..                       ..
# 479327                                   ..                       ..
#
#        acs_lvl_gs-3_acs_cycling acs_lvl_gs-3_acs_public_transit_offpeak  \
# 479323                       ..                                      ..
# 479324                       ..                                      ..
# 479325                       ..                                      ..
# 479326                       ..                                      ..
# 479327                       ..                                      ..
#
#        acs_lvl_gs-3_acs_public_transit_peak acs_lvl_gs-3_acs_walking  \
# 479323                                   ..                       ..
# 479324                                   ..                       ..
# 479325                                   ..                       ..
# 479326                                   ..                       ..
# 479327                                   ..                       ..
#
#        acs_lvl_gs-5_acs_cycling acs_lvl_gs-5_acs_public_transit_offpeak  \
# 479323                       ..                                      ..
# 479324                       ..                                      ..
# 479325                       ..                                      ..
# 479326                       ..                                      ..
# 479327                       ..                                      ..
#
#        acs_lvl_gs-5_acs_public_transit_peak acs_lvl_gs-5_acs_walking
# 479323                                   ..                       ..
# 479324                                   ..                       ..
# 479325                                   ..                       ..
# 479326                                   ..                       ..
# 479327                                   ..                       ..
#
# [5 rows x 40 columns]

# %%
import pyarrow.parquet as pq

# Recommended row group size https://duckdb.org/docs/stable/guides/performance/file_formats.html#microbenchmark-running-aggregation-query-at-different-row-group-sizes
df_flat.to_parquet(
    "spatial_access_measures_wkb.parquet",
    geometry_encoding="WKB",
    schema_version="1.1.0",
    compression="brotli",
    row_group_size=61440,
    sorting_columns=[pq.SortingColumn(1)],
)
